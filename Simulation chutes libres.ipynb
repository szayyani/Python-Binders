# %%
import numpy as np
import matplotlib.pyplot as plt
import math as m
import scipy as sc

# %% [markdown]
# Commençons par une chute libre en 1-D :
# Nous voulons calculez différentes grandeurs, temps de chute, vitesse au moment du contacte avec le sol, et on aimerait tracer la trajectoire quand on arrive en 2-D.
#
# ---
